# %% [markdown]
# # 1. Load Repo

# %%
# %cd /kaggle/working
# !rm -rf /kaggle/working/well-log-imputation
# !git clone https://github.com/tranminhduc9/well-log-imputation.git /kaggle/working/well-log-imputation
# %cd /kaggle/working/well-log-imputation
# Out:
# /kaggle/working
# Cloning into '/kaggle/working/well-log-imputation'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 58 (delta 20), reused 55 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 47.88 KiB | 15.96 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /kaggle/working/well-log-imputation

# %% [markdown]
# # 2. Requirements

# %%
# !cat requirements.txt
# Out:
# # Python 3.12 / Kaggle-compatible dependencies. Lower bounds allow Kaggle to
# # keep its newer preinstalled scientific and CUDA stack instead of downgrading.
# numpy>=2.0,<3
# pandas>=2.2
# scipy>=1.14.1
# scikit-learn>=1.6
# torch>=2.10
# xgboost>=3.0
#
# pypots==0.3.2
# pygrinder==0.7
# tsdb==0.8
# monai>=1.3.2,<2
#
# # Data preprocessing.
# lasio==0.31
# missingno==0.5.2
#
# # Plotting and progress reporting.
# matplotlib>=3.9
# seaborn>=0.13.2
# tqdm>=4.67

# %%
# !python -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: scipy>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: torch>=2.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.10.0+cu128)
# Requirement already satisfied: xgboost>=3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.2.0)
# Collecting pypots==0.3.2 (from -r requirements.txt (line 10))
#   Downloading pypots-0.3.2-py3-none-any.whl.metadata (29 kB)
# Collecting pygrinder==0.7 (from -r requirements.txt (line 11))
#   Downloading pygrinder-0.7-py3-none-any.whl.metadata (10 kB)
# Collecting tsdb==0.8 (from -r requirements.txt (line 12))
#   Downloading tsdb-0.8-py3-none-any.whl.metadata (13 kB)
# Collecting monai<2,>=1.3.2 (from -r requirements.txt (line 13))
#   Downloading monai-1.6.0-202606221745-py3-none-any.whl.metadata (14 kB)
# Collecting lasio==0.31 (from -r requirements.txt (line 16))
#   Downloading lasio-0.31-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: missingno==0.5.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (0.5.2)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (3.10.0)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (0.13.2)
# Requirement already satisfied: tqdm>=4.67 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (4.67.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from pypots==0.3.2->-r requirements.txt (line 10)) (3.16.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from pypots==0.3.2->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tsdb==0.8->-r requirements.txt (line 12)) (24.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tsdb==0.8->-r requirements.txt (line 12)) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->-r requirements.txt (line 4)) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.10->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.10->-r requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->-r requirements.txt (line 20)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->-r requirements.txt (line 20)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->-r requirements.txt (line 20)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->-r requirements.txt (line 20)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->-r requirements.txt (line 20)) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->-r requirements.txt (line 20)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->-r requirements.txt (line 20)) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.10->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.10->-r requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tsdb==0.8->-r requirements.txt (line 12)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tsdb==0.8->-r requirements.txt (line 12)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tsdb==0.8->-r requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tsdb==0.8->-r requirements.txt (line 12)) (2026.4.22)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->pypots==0.3.2->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->pypots==0.3.2->-r requirements.txt (line 10)) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->pypots==0.3.2->-r requirements.txt (line 10)) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->pypots==0.3.2->-r requirements.txt (line 10)) (5.29.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->pypots==0.3.2->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->pypots==0.3.2->-r requirements.txt (line 10)) (3.1.8)
# Downloading pypots-0.3.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.0/245.0 kB 16.0 MB/s eta 0:00:00
# Downloading pygrinder-0.7-py3-none-any.whl (24 kB)
# Downloading tsdb-0.8-py3-none-any.whl (34 kB)
# Downloading lasio-0.31-py2.py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 3.3 MB/s eta 0:00:00
# Downloading monai-1.6.0-202606221745-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.2 MB/s eta 0:00:00
# Installing collected packages: lasio, tsdb, pygrinder, monai, pypots
# Successfully installed lasio-0.31 monai-1.6.0 pygrinder-0.7 pypots-0.3.2 tsdb-0.8

# %% [markdown]
# # 3. Running code

# %%
from pathlib import Path

matches = list(Path("/kaggle/input").rglob("geolink_fold_0_well_log_sliced_train.npy"))
assert matches, "Không tìm thấy dataset Geolink trong /kaggle/input"

DATA_DIR = str(matches[0].parent)
OUTPUT_DIR = "/kaggle/working/output"

print("DATA_DIR:", DATA_DIR)
# !mkdir -p {OUTPUT_DIR}
# Out:
# DATA_DIR: /kaggle/input/datasets/minhduc0912/well-log-geolink/pgeoprj/godeep/dados/l2_datasets/imputation-processed-datasets

# %% [markdown]
# ## 3.1. Models

# %% [markdown]
# ### a. LOCF

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model locf --output_dir {OUTPUT_DIR}/locf
# Out:
# Using compute device: cuda
# 2026-08-12 07:53:46 [INFO]: Have set the random seed as 17076 for numpy and pytorch.
#
#
# training model: locf...
# 2026-08-12 07:53:46 [INFO]: No given device, using default device: cuda
#
# training in fold 0...
# final training time in fold 0: 0m 1s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.0449
# masking single.1 testing mean squared error:0.0065
# masking single.1 testing mean root-mean squared error:0.0808
# masking single.1 testing mean r2:0.9922
# masking single.1 testing correlation:0.9961
# mode block.20...
# masking block.20 testing mean absolute error:0.1292
# masking block.20 testing mean squared error:0.0760
# masking block.20 testing mean root-mean squared error:0.2756
# masking block.20 testing mean r2:0.9117
# masking block.20 testing correlation:0.9565
# mode block.100...
# masking block.100 testing mean absolute error:0.1480
# masking block.100 testing mean squared error:0.0750
# masking block.100 testing mean root-mean squared error:0.2739
# masking block.100 testing mean r2:0.8962
# masking block.100 testing correlation:0.9477
# mode profile...
# masking profile testing mean absolute error:0.6371
# masking profile testing mean squared error:0.7568
# masking profile testing mean root-mean squared error:0.8699
# masking profile testing mean r2:-0.0001
# masking profile testing correlation:0.0000
# 2026-08-12 07:53:48 [INFO]: No given device, using default device: cuda
#
# training in fold 1...
# final training time in fold 1: 0m 0s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.0410
# masking single.1 testing mean squared error:0.0077
# masking single.1 testing mean root-mean squared error:0.0878
# masking single.1 testing mean r2:0.9890
# masking single.1 testing correlation:0.9945
# mode block.20...
# masking block.20 testing mean absolute error:0.1229
# masking block.20 testing mean squared error:0.0561
# masking block.20 testing mean root-mean squared error:0.2368
# masking block.20 testing mean r2:0.9163
# masking block.20 testing correlation:0.9586
# mode block.100...
# masking block.100 testing mean absolute error:0.1779
# masking block.100 testing mean squared error:0.1161
# masking block.100 testing mean root-mean squared error:0.3407
# masking block.100 testing mean r2:0.8276
# masking block.100 testing correlation:0.9130
# mode profile...
# masking profile testing mean absolute error:0.6710
# masking profile testing mean squared error:0.7048
# masking profile testing mean root-mean squared error:0.8395
# masking profile testing mean r2:-0.0000
# masking profile testing correlation:0.0000
# 2026-08-12 07:53:49 [INFO]: No given device, using default device: cuda
#
# training in fold 2...
# final training time in fold 2: 0m 0s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.0456
# masking single.1 testing mean squared error:0.0080
# masking single.1 testing mean root-mean squared error:0.0894
# masking single.1 testing mean r2:0.9901
# masking single.1 testing correlation:0.9951
# mode block.20...
# masking block.20 testing mean absolute error:0.1388
# masking block.20 testing mean squared error:0.0704
# masking block.20 testing mean root-mean squared error:0.2653
# masking block.20 testing mean r2:0.8985
# masking block.20 testing correlation:0.9513
# mode block.100...
# masking block.100 testing mean absolute error:0.1889
# masking block.100 testing mean squared error:0.1401
# masking block.100 testing mean root-mean squared error:0.3743
# masking block.100 testing mean r2:0.8503
# masking block.100 testing correlation:0.9281
# mode profile...
# masking profile testing mean absolute error:0.6368
# masking profile testing mean squared error:0.7781
# masking profile testing mean root-mean squared error:0.8821
# masking profile testing mean r2:-0.0018
# masking profile testing correlation:0.0000
# 2026-08-12 07:53:50 [INFO]: No given device, using default device: cuda
#
# training in fold 3...
# final training time in fold 3: 0m 0s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.0546
# masking single.1 testing mean squared error:0.0145
# masking single.1 testing mean root-mean squared error:0.1203
# masking single.1 testing mean r2:0.9796
# masking single.1 testing correlation:0.9898
# mode block.20...
# masking block.20 testing mean absolute error:0.1387
# masking block.20 testing mean squared error:0.0711
# masking block.20 testing mean root-mean squared error:0.2666
# masking block.20 testing mean r2:0.9087
# masking block.20 testing correlation:0.9542
# mode block.100...
# masking block.100 testing mean absolute error:0.1758
# masking block.100 testing mean squared error:0.1114
# masking block.100 testing mean root-mean squared error:0.3338
# masking block.100 testing mean r2:0.8366
# masking block.100 testing correlation:0.9191
# mode profile...
# masking profile testing mean absolute error:0.6207
# masking profile testing mean squared error:0.7301
# masking profile testing mean root-mean squared error:0.8544
# masking profile testing mean r2:-0.0039
# masking profile testing correlation:0.0000
# 2026-08-12 07:53:51 [INFO]: No given device, using default device: cuda
#
# training in fold 4...
# final training time in fold 4: 0m 0s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.0441
# masking single.1 testing mean squared error:0.0090
# masking single.1 testing mean root-mean squared error:0.0950
# masking single.1 testing mean r2:0.9867
# masking single.1 testing correlation:0.9933
# mode block.20...
# masking block.20 testing mean absolute error:0.1409
# masking block.20 testing mean squared error:0.0901
# masking block.20 testing mean root-mean squared error:0.3002
# masking block.20 testing mean r2:0.8706
# masking block.20 testing correlation:0.9365
# mode block.100...
# masking block.100 testing mean absolute error:0.1755
# masking block.100 testing mean squared error:0.1128
# masking block.100 testing mean root-mean squared error:0.3359
# masking block.100 testing mean r2:0.8209
# masking block.100 testing correlation:0.9117
# mode profile...
# masking profile testing mean absolute error:0.6223
# masking profile testing mean squared error:0.6788
# masking profile testing mean root-mean squared error:0.8239
# masking profile testing mean r2:-0.0001
# masking profile testing correlation:0.0000
# final training time: 0m 5s
# ----------------------------------------------
#
#
# training-time:	 1.0000	0.0000	0.0000	0.0000	0.0000
# validation-mae-single.1:	 0.0449	0.0410	0.0456	0.0546	0.0441
# validation-mse-single.1:	 0.0065	0.0077	0.0080	0.0145	0.0090
# validation-rmse-single.1:	 0.0808	0.0878	0.0894	0.1203	0.0950
# validation-r2-single.1:	 0.9922	0.9890	0.9901	0.9796	0.9867
# validation-cc-single.1:	 0.9961	0.9945	0.9951	0.9898	0.9933
# validation-mae-block.20:	 0.1292	0.1229	0.1388	0.1387	0.1409
# validation-mse-block.20:	 0.0760	0.0561	0.0704	0.0711	0.0901
# validation-rmse-block.20:	 0.2756	0.2368	0.2653	0.2666	0.3002
# validation-r2-block.20:	 0.9117	0.9163	0.8985	0.9087	0.8706
# validation-cc-block.20:	 0.9565	0.9586	0.9513	0.9542	0.9365
# validation-mae-block.100:	 0.1480	0.1779	0.1889	0.1758	0.1755
# validation-mse-block.100:	 0.0750	0.1161	0.1401	0.1114	0.1128
# validation-rmse-block.100:	 0.2739	0.3407	0.3743	0.3338	0.3359
# validation-r2-block.100:	 0.8962	0.8276	0.8503	0.8366	0.8209
# validation-cc-block.100:	 0.9477	0.9130	0.9281	0.9191	0.9117
# validation-mae-profile:	 0.6371	0.6710	0.6368	0.6207	0.6223
# validation-mse-profile:	 0.7568	0.7048	0.7781	0.7301	0.6788
# validation-rmse-profile:	 0.8699	0.8395	0.8821	0.8544	0.8239
# validation-r2-profile:	 -0.0001	-0.0000	-0.0018	-0.0039	-0.0001
# validation-cc-profile:	 0.0000	0.0000	0.0000	0.0000	0.0000

# %% [markdown]
# ### b. Random Forest

# %%
#!python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model rf --output_dir {OUTPUT_DIR}/rf
# Out:
# Using compute device: cuda
# 2026-08-12 07:54:02 [INFO]: Have set the random seed as 17076 for numpy and pytorch.
#
#
# training model: rf...
#
# training in fold 0...
# training model in training set and tracking performance in validation set..
# ^C

# %% [markdown]
# ### c. Quantile Random Forest (90% prediction interval)

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model qrf --output_dir {OUTPUT_DIR}/qrf

# %% [markdown]
# ### d. Bayesian Neural Network (MC Dropout, 90% prediction interval)

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model bayesnn --output_dir {OUTPUT_DIR}/bayesnn

# %% [markdown]
# ### e. XGBoost

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model xgboost --output_dir {OUTPUT_DIR}/xgboost
# Out:
# Using compute device: cuda
# 2026-08-12 08:31:26 [INFO]: Have set the random seed as 17076 for numpy and pytorch.
#
#
# training model: xgboost...
#
# training in fold 0...
# training model in training set and tracking performance in validation set..
# final training time in fold 0: 0m 5s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.3961
# masking single.1 testing mean squared error:0.4815
# masking single.1 testing mean root-mean squared error:0.6939
# masking single.1 testing mean r2:0.4285
# masking single.1 testing correlation:0.6744
# mode block.20...
# masking block.20 testing mean absolute error:0.3999
# masking block.20 testing mean squared error:0.5101
# masking block.20 testing mean root-mean squared error:0.7142
# masking block.20 testing mean r2:0.4073
# masking block.20 testing correlation:0.6547
# mode block.100...
# masking block.100 testing mean absolute error:0.3574
# masking block.100 testing mean squared error:0.3792
# masking block.100 testing mean root-mean squared error:0.6158
# masking block.100 testing mean r2:0.4750
# masking block.100 testing correlation:0.7052
# mode profile...
# masking profile testing mean absolute error:0.3670
# masking profile testing mean squared error:0.3893
# masking profile testing mean root-mean squared error:0.6239
# masking profile testing mean r2:0.4856
# masking profile testing correlation:0.7138
#
# training in fold 1...
# training model in training set and tracking performance in validation set..
# final training time in fold 1: 0m 4s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.4071
# masking single.1 testing mean squared error:0.3529
# masking single.1 testing mean root-mean squared error:0.5941
# masking single.1 testing mean r2:0.4975
# masking single.1 testing correlation:0.7155
# mode block.20...
# masking block.20 testing mean absolute error:0.3932
# masking block.20 testing mean squared error:0.3125
# masking block.20 testing mean root-mean squared error:0.5590
# masking block.20 testing mean r2:0.5337
# masking block.20 testing correlation:0.7374
# mode block.100...
# masking block.100 testing mean absolute error:0.4141
# masking block.100 testing mean squared error:0.3518
# masking block.100 testing mean root-mean squared error:0.5932
# masking block.100 testing mean r2:0.4775
# masking block.100 testing correlation:0.6991
# mode profile...
# masking profile testing mean absolute error:0.4156
# masking profile testing mean squared error:0.3582
# masking profile testing mean root-mean squared error:0.5985
# masking profile testing mean r2:0.4917
# masking profile testing correlation:0.7115
#
# training in fold 2...
# training model in training set and tracking performance in validation set..
# final training time in fold 2: 0m 4s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.4032
# masking single.1 testing mean squared error:0.4924
# masking single.1 testing mean root-mean squared error:0.7017
# masking single.1 testing mean r2:0.3916
# masking single.1 testing correlation:0.6378
# mode block.20...
# masking block.20 testing mean absolute error:0.3684
# masking block.20 testing mean squared error:0.3403
# masking block.20 testing mean root-mean squared error:0.5834
# masking block.20 testing mean r2:0.5092
# masking block.20 testing correlation:0.7287
# mode block.100...
# masking block.100 testing mean absolute error:0.4223
# masking block.100 testing mean squared error:0.6087
# masking block.100 testing mean root-mean squared error:0.7802
# masking block.100 testing mean r2:0.3497
# masking block.100 testing correlation:0.6026
# mode profile...
# masking profile testing mean absolute error:0.3903
# masking profile testing mean squared error:0.4501
# masking profile testing mean root-mean squared error:0.6709
# masking profile testing mean r2:0.4206
# masking profile testing correlation:0.6586
#
# training in fold 3...
# training model in training set and tracking performance in validation set..
# final training time in fold 3: 0m 4s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.3921
# masking single.1 testing mean squared error:0.3838
# masking single.1 testing mean root-mean squared error:0.6195
# masking single.1 testing mean r2:0.4590
# masking single.1 testing correlation:0.6864
# mode block.20...
# masking block.20 testing mean absolute error:0.4111
# masking block.20 testing mean squared error:0.4573
# masking block.20 testing mean root-mean squared error:0.6762
# masking block.20 testing mean r2:0.4126
# masking block.20 testing correlation:0.6556
# mode block.100...
# masking block.100 testing mean absolute error:0.3888
# masking block.100 testing mean squared error:0.3950
# masking block.100 testing mean root-mean squared error:0.6285
# masking block.100 testing mean r2:0.4207
# masking block.100 testing correlation:0.6553
# mode profile...
# masking profile testing mean absolute error:0.3997
# masking profile testing mean squared error:0.4467
# masking profile testing mean root-mean squared error:0.6683
# masking profile testing mean r2:0.3858
# masking profile testing correlation:0.6291
#
# training in fold 4...
# training model in training set and tracking performance in validation set..
# final training time in fold 4: 0m 4s
# calculate validation set imputation...
# mode single.1...
# masking single.1 testing mean absolute error:0.4188
# masking single.1 testing mean squared error:0.4014
# masking single.1 testing mean root-mean squared error:0.6335
# masking single.1 testing mean r2:0.4061
# masking single.1 testing correlation:0.6416
# mode block.20...
# masking block.20 testing mean absolute error:0.4297
# masking block.20 testing mean squared error:0.4021
# masking block.20 testing mean root-mean squared error:0.6341
# masking block.20 testing mean r2:0.4225
# masking block.20 testing correlation:0.6636
# mode block.100...
# masking block.100 testing mean absolute error:0.4130
# masking block.100 testing mean squared error:0.3557
# masking block.100 testing mean root-mean squared error:0.5964
# masking block.100 testing mean r2:0.4354
# masking block.100 testing correlation:0.6642
# mode profile...
# masking profile testing mean absolute error:0.4088
# masking profile testing mean squared error:0.3987
# masking profile testing mean root-mean squared error:0.6314
# masking profile testing mean r2:0.4126
# masking profile testing correlation:0.6480
# final training time: 0m 25s
# ----------------------------------------------
#
#
# training-time:	 5.0000	4.0000	4.0000	4.0000	4.0000
# validation-mae-single.1:	 0.3961	0.4071	0.4032	0.3921	0.4188
# validation-mse-single.1:	 0.4815	0.3529	0.4924	0.3838	0.4014
# validation-rmse-single.1:	 0.6939	0.5941	0.7017	0.6195	0.6335
# validation-r2-single.1:	 0.4285	0.4975	0.3916	0.4590	0.4061
# validation-cc-single.1:	 0.6744	0.7155	0.6378	0.6864	0.6416
# validation-mae-block.20:	 0.3999	0.3932	0.3684	0.4111	0.4297
# validation-mse-block.20:	 0.5101	0.3125	0.3403	0.4573	0.4021
# validation-rmse-block.20:	 0.7142	0.5590	0.5834	0.6762	0.6341
# validation-r2-block.20:	 0.4073	0.5337	0.5092	0.4126	0.4225
# validation-cc-block.20:	 0.6547	0.7374	0.7287	0.6556	0.6636
# validation-mae-block.100:	 0.3574	0.4141	0.4223	0.3888	0.4130
# validation-mse-block.100:	 0.3792	0.3518	0.6087	0.3950	0.3557
# validation-rmse-block.100:	 0.6158	0.5932	0.7802	0.6285	0.5964
# validation-r2-block.100:	 0.4750	0.4775	0.3497	0.4207	0.4354
# validation-cc-block.100:	 0.7052	0.6991	0.6026	0.6553	0.6642
# validation-mae-profile:	 0.3670	0.4156	0.3903	0.3997	0.4088
# validation-mse-profile:	 0.3893	0.3582	0.4501	0.4467	0.3987
# validation-rmse-profile:	 0.6239	0.5985	0.6709	0.6683	0.6314
# validation-r2-profile:	 0.4856	0.4917	0.4206	0.3858	0.4126
# validation-cc-profile:	 0.7138	0.7115	0.6586	0.6291	0.6480

# %% [markdown]
# ### d. Autoencoder

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model ae --output_dir {OUTPUT_DIR}/ae
# Out:
# Using compute device: cuda
# 2026-08-12 08:35:18 [INFO]: Have set the random seed as 17076 for numpy and pytorch.
#
#
# training model: ae...
# 2026-08-12 08:35:18 [INFO]: Using the given device: cuda
# 2026-08-12 08:35:18 [INFO]: Model files will be saved to /kaggle/working/output/ae/ae/20260812_T083518
# 2026-08-12 08:35:18 [INFO]: Tensorboard file will be saved to /kaggle/working/output/ae/ae/20260812_T083518/tensorboard
# 2026-08-12 08:35:18 [INFO]: AENet initialized with the given hyperparameters, the number of trainable parameters: 284,064
#
# training in fold 0...
# training model in training set and tracking performance in validation set..
# 2026-08-12 08:35:23 [INFO]: epoch 0: training loss 0.2280, validating loss 0.1100
# 2026-08-12 08:35:23 [INFO]: epoch 1: training loss 0.0945, validating loss 0.0827
# 2026-08-12 08:35:24 [INFO]: epoch 2: training loss 0.0778, validating loss 0.0714
# 2026-08-12 08:35:25 [INFO]: epoch 3: training loss 0.0737, validating loss 0.0659
# 2026-08-12 08:35:26 [INFO]: epoch 4: training loss 0.0676, validating loss 0.0599
# 2026-08-12 08:35:26 [INFO]: epoch 5: training loss 0.0624, validating loss 0.0568
# 2026-08-12 08:35:27 [INFO]: epoch 6: training loss 0.0609, validating loss 0.0566
# 2026-08-12 08:35:28 [INFO]: epoch 7: training loss 0.0593, validating loss 0.0546
# 2026-08-12 08:35:29 [INFO]: epoch 8: training loss 0.0578, validating loss 0.0541
# 2026-08-12 08:35:29 [INFO]: epoch 9: training loss 0.0573, validating loss 0.0540
# 2026-08-12 08:35:30 [INFO]: epoch 10: training loss 0.0573, validating loss 0.0506
# 2026-08-12 08:35:31 [INFO]: epoch 11: training loss 0.0549, validating loss 0.0511
# 2026-08-12 08:35:32 [INFO]: epoch 12: training loss 0.0520, validating loss 0.0486
# 2026-08-12 08:37:37 [INFO]: epoch 182: training loss 0.0270, validating loss 0.0306
# 2026-08-12 08:37:38 [INFO]: epoch 183: training loss 0.0275, validating loss 0.0319
# 2026-08-12 08:37:38 [INFO]: epoch 184: training loss 0.0273, validating loss 0.0306
# 2026-08-12 08:37:39 [INFO]: epoch 185: training loss 0.0274, validating loss 0.0308
# 2026-08-12 08:37:40 [INFO]: epoch 186: training loss 0.0272, validating loss 0.0318
# 2026-08-12 08:37:41 [INFO]: epoch 187: training loss 0.0275, validating loss 0.0307
# 2026-08-12 08:37:41 [INFO]: epoch 188: training loss 0.0274, validating loss 0.0312
# 2026-08-12 08:37:42 [INFO]: epoch 189: training loss 0.0270, validating loss 0.0312
# 2026-08-12 08:37:43 [INFO]: epoch 190: training loss 0.0271, validating loss 0.0308
# 2026-08-12 08:37:44 [INFO]: epoch 191: training loss 0.0272, validating loss 0.0315
# 2026-08-12 08:37:44 [INFO]: epoch 192: training loss 0.0278, validating loss 0.0328
# 2026-08-12 08:37:45 [INFO]: epoch 193: training loss 0.0317, validating loss 0.0342
# 2026-08-12 08:37:46 [INFO]: epoch 194: training loss 0.0281, validating loss 0.0308
# 2026-08-12 08:37:47 [INFO]: epoch 195: training loss 0.0268, validating loss 0.0304
# 2026-08-12 08:37:47 [INFO]: epoch 196: training loss 0.0266, validating loss 0.0308
# 2026-08-12 08:37:48 [INFO]: epoch 197: training loss 0.0274, validating loss 0.0315
# 2026-08-12 08:37:49 [INFO]: epoch 198: training loss 0.0272, validating loss 0.0304
# 2026-08-12 08:37:50 [INFO]: epoch 199: training loss 0.0265, validating loss 0.0308
# 2026-08-12 08:37:50 [INFO]: epoch 200: training loss 0.0268, validating loss 0.0307
# 2026-08-12 08:37:51 [INFO]: epoch 201: training loss 0.0269, validating loss 0.0304
# 2026-08-12 08:37:52 [INFO]: epoch 202: training loss 0.0269, validating loss 0.0312
# 2026-08-12 08:37:52 [INFO]: epoch 203: training loss 0.0295, validating loss 0.0342
# 2026-08-12 08:37:53 [INFO]: epoch 204: training loss 0.0285, validating loss 0.0311
# 2026-08-12 08:37:54 [INFO]: epoch 205: training loss 0.0273, validating loss 0.0319
# 2026-08-12 08:37:55 [INFO]: epoch 206: training loss 0.0271, validating loss 0.0309
# 2026-08-12 08:37:55 [INFO]: epoch 207: training loss 0.0267, validating loss 0.0306
# 2026-08-12 08:37:56 [INFO]: epoch 208: training loss 0.0267, validating loss 0.0308
# 2026-08-12 08:37:57 [INFO]: epoch 209: training loss 0.0268, validating loss 0.0313
# 2026-08-12 08:37:58 [INFO]: epoch 210: training loss 0.0268, validating loss 0.0311
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/well-log-imputation/main.py", line 280, in <module>
#     main(cfg)
#   File "/kaggle/working/well-log-imputation/main.py", line 272, in main
#     metrics = run_experiments(model, cfg.experiments, cfg.n_folds, cfg.dataset_name, cfg.dataset_dir, model_name=cfg.model)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/well-log-imputation/main.py", line 178, in run_experiments
#     model.fit(train_set=dataset_for_training, val_set=dataset_for_validating['rand'])
#   File "/kaggle/working/well-log-imputation/models/autoencoder.py", line 279, in fit
#     self._train_model(training_loader, val_loader)
#   File "/kaggle/working/well-log-imputation/models/autoencoder.py", line 146, in _train_model
#     for idx, data in enumerate(training_loader):
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 801, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 54, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/kaggle/working/well-log-imputation/data/datasets.py", line 55, in __getitem__
#     missing_mask = missing_mask.to(torch.float32)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# ### e. BRITS

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model brits --output_dir {OUTPUT_DIR}/brits
# Out:
# Using compute device: cuda
# 2026-08-12 08:38:11 [INFO]: Have set the random seed as 17076 for numpy and pytorch.
#
#
# training model: brits...
# 2026-08-12 08:38:11 [INFO]: Using the given device: cuda
# 2026-08-12 08:38:11 [INFO]: Model files will be saved to /kaggle/working/output/brits/brits/20260812_T083811
# 2026-08-12 08:38:11 [INFO]: Tensorboard file will be saved to /kaggle/working/output/brits/brits/20260812_T083811/tensorboard
# 2026-08-12 08:38:11 [INFO]: BRITS initialized with the given hyperparameters, the number of trainable parameters: 143,776
#
# training in fold 0...
# training model in training set and tracking performance in validation set..
# 2026-08-12 08:42:53 [INFO]: Epoch 001 - training loss: 0.8120, validating loss: 0.6107
# 2026-08-12 08:46:40 [INFO]: Epoch 002 - training loss: 0.5650, validating loss: 0.5598
# 2026-08-12 08:50:28 [INFO]: Epoch 003 - training loss: 0.4843, validating loss: 0.5642
# 2026-08-12 08:54:13 [INFO]: Epoch 004 - training loss: 0.4349, validating loss: 0.5650
# 2026-08-12 08:57:58 [INFO]: Epoch 005 - training loss: 0.4002, validating loss: 0.5721
# 2026-08-12 09:01:43 [INFO]: Epoch 006 - training loss: 0.3769, validating loss: 0.5994
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/well-log-imputation/main.py", line 280, in <module>
#     main(cfg)
#   File "/kaggle/working/well-log-imputation/main.py", line 272, in main
#     metrics = run_experiments(model, cfg.experiments, cfg.n_folds, cfg.dataset_name, cfg.dataset_dir, model_name=cfg.model)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/well-log-imputation/main.py", line 178, in run_experiments
#     model.fit(train_set=dataset_for_training, val_set=dataset_for_validating['rand'])
#   File "/usr/local/lib/python3.12/dist-packages/pypots/imputation/brits/model.py", line 231, in fit
#     self._train_model(training_loader, val_loader)
#   File "/usr/local/lib/python3.12/dist-packages/pypots/imputation/base.py", line 297, in _train_model
#     results = self.model.forward(inputs, training=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pypots/imputation/brits/modules/core.py", line 304, in forward
#     ret_b = self._reverse(self.rits_b(inputs, "backward"))
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pypots/imputation/brits/modules/core.py", line 193, in forward
#     imputed_data, hidden_state, reconstruction_loss = self.impute(inputs, direction)
#                                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pypots/imputation/brits/modules/core.py", line 163, in impute
#     reconstruction_loss += calc_mae(c_h, x, m)
#                            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pypots/utils/metrics/error.py", line 106, in calc_mae
#     lib = _check_inputs(predictions, targets, masks)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pypots/utils/metrics/error.py", line 38, in _check_inputs
#     ).any(), "`predictions` mustn't contain NaN values, but detected NaN in it"
#       ^^^^^
# KeyboardInterrupt

# %% [markdown]
# ### g. UNet

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model unet --output_dir {OUTPUT_DIR}/unet
# Out:
# Using compute device: cuda
# 2026-08-12 09:05:19 [INFO]: Have set the random seed as 17076 for numpy and pytorch.
#
#
# training model: unet...
# 2026-08-12 09:05:44 [INFO]: Using the given device: cuda
# 2026-08-12 09:05:44 [INFO]: Model files will be saved to /kaggle/working/output/unet/unet/20260812_T090544
# 2026-08-12 09:05:44 [INFO]: Tensorboard file will be saved to /kaggle/working/output/unet/unet/20260812_T090544/tensorboard
# 2026-08-12 09:05:44 [INFO]: UNet initialized with the given hyperparameters, the number of trainable parameters: 1,207,236
#
# training in fold 0...
# training model in training set and tracking performance in validation set..
# 2026-08-12 09:05:47 [INFO]: epoch 0: training loss 4.9039, validating loss 0.5377
# 2026-08-12 09:05:49 [INFO]: epoch 1: training loss 4.1050, validating loss 0.4861
# 2026-08-12 09:05:51 [INFO]: epoch 2: training loss 3.4983, validating loss 0.4627
# 2026-08-12 09:05:53 [INFO]: epoch 3: training loss 3.2178, validating loss 0.4344
# 2026-08-12 09:05:55 [INFO]: epoch 4: training loss 2.9418, validating loss 0.4135
# 2026-08-12 09:05:56 [INFO]: epoch 5: training loss 2.7573, validating loss 0.4088
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/well-log-imputation/main.py", line 280, in <module>
#     main(cfg)
#   File "/kaggle/working/well-log-imputation/main.py", line 272, in main
#     metrics = run_experiments(model, cfg.experiments, cfg.n_folds, cfg.dataset_name, cfg.dataset_dir, model_name=cfg.model)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/well-log-imputation/main.py", line 178, in run_experiments
#     model.fit(train_set=dataset_for_training, val_set=dataset_for_validating['rand'])
#   File "/kaggle/working/well-log-imputation/models/unet.py", line 272, in fit
#     self._train_model(training_loader, val_loader)
#   File "/kaggle/working/well-log-imputation/models/unet.py", line 169, in _train_model
#     for idx, data in enumerate(val_loader):
#                      ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 801, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 54, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/kaggle/working/well-log-imputation/data/datasets.py", line 56, in __getitem__
#     X = torch.nan_to_num(X)
#         ^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# ### h. SAITS

# %%
# !python main.py --dataset_name geolink --dataset_dir {DATA_DIR} --model saits --output_dir {OUTPUT_DIR}/saits
# Out:
# Using compute device: cuda
# 2026-08-12 09:06:09 [INFO]: Have set the random seed as 17076 for numpy and pytorch.
#
#
# training model: saits...
# 2026-08-12 09:06:09 [INFO]: Using the given device: cuda
# 2026-08-12 09:06:09 [INFO]: Model files will be saved to /kaggle/working/output/saits/saits/20260812_T090609
# 2026-08-12 09:06:09 [INFO]: Tensorboard file will be saved to /kaggle/working/output/saits/saits/20260812_T090609/tensorboard
# 2026-08-12 09:06:09 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,324,080
#
# training in fold 0...
# training model in training set and tracking performance in validation set..
# 2026-08-12 09:06:19 [INFO]: Epoch 001 - training loss: 0.5784, validating loss: 0.5170
# 2026-08-12 09:06:27 [INFO]: Epoch 002 - training loss: 0.4080, validating loss: 0.5743
# 2026-08-12 09:06:35 [INFO]: Epoch 003 - training loss: 0.3617, validating loss: 0.5582
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/well-log-imputation/main.py", line 280, in <module>
#     main(cfg)
#   File "/kaggle/working/well-log-imputation/main.py", line 272, in main
#     metrics = run_experiments(model, cfg.experiments, cfg.n_folds, cfg.dataset_name, cfg.dataset_dir, model_name=cfg.model)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/well-log-imputation/main.py", line 178, in run_experiments
#     model.fit(train_set=dataset_for_training, val_set=dataset_for_validating['rand'])
#   File "/usr/local/lib/python3.12/dist-packages/pypots/imputation/saits/model.py", line 282, in fit
#     self._train_model(training_loader, val_loader)
#   File "/usr/local/lib/python3.12/dist-packages/pypots/imputation/base.py", line 282, in _train_model
#     epoch_train_loss_collector.append(results["loss"].sum().item())
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# ## 3.2 Visualize Results

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# Read metric summaries written by the model cells to OUTPUT_DIR.
# If a log contains several runs, use the latest value for each metric.
summary_pattern = re.compile(
    r"^(training-time|inference-time-[^:]+|validation-(?:mae|mse|rmse|r2|cc)-[^:]+):\s*(.+)$"
)
metric_records = []
inference_records = []
loaded_logs = []

for log_path in sorted(Path(OUTPUT_DIR).rglob("*_*.log")):
    model, dataset = log_path.stem.split("_", 1)
    latest_summary = {}

    for line in log_path.read_text(errors="replace").splitlines():
        match = summary_pattern.match(line.strip())
        if match:
            try:
                latest_summary[match.group(1)] = [
                    float(value) for value in match.group(2).split()
                ]
            except ValueError:
                continue

    validation_rows = {
        label: values for label, values in latest_summary.items()
        if label.startswith("validation-")
    }
    if not validation_rows:
        print(f"Skip {log_path.name}: no completed metric summary")
        continue

    loaded_logs.append(log_path.name)
    for label, values in validation_rows.items():
        division_type, metric, mode = label.split("-", 2)
        for fold, value in enumerate(values):
            metric_records.append([model, dataset, division_type, metric, mode, value, fold])

    for label, values in latest_summary.items():
        if not label.startswith("inference-time-"):
            continue
        mode = label.removeprefix("inference-time-")
        for fold, seconds in enumerate(values):
            inference_records.append([model, dataset, mode, seconds, fold])

metrics_df = pd.DataFrame(
    metric_records,
    columns=["Model", "Dataset", "Division type", "Metric", "Mode", "Value", "Fold"],
)
inference_df = pd.DataFrame(
    inference_records,
    columns=["Model", "Dataset", "Mode", "Seconds", "Fold"],
)
assert not metrics_df.empty, f"No completed model metrics found under {OUTPUT_DIR}"

print("Loaded completed results from:", ", ".join(loaded_logs))
display(metrics_df.head())

# %%
model_names = {
    "ae": "AE", "brits": "BRITS", "locf": "LOCF", "mrnn": "mRNN",
    "rf": "RF", "saits": "SAITS", "svm": "SVM",
    "transformer": "Transformer", "unet": "U-Net", "xgboost": "XGBoost",
}
mode_names = {
    "single": "Single", "single.1": "Single",
    "block.20": "Block 20", "block.100": "Block 100", "profile": "Profile",
}
dataset_names = {"taranaki": "Taranaki", "geolink": "Geolink", "teapot": "Teapot"}

plot_df = metrics_df.copy()
plot_df["Model"] = plot_df["Model"].replace(model_names)
plot_df["Mode"] = plot_df["Mode"].replace(mode_names)
plot_df["Dataset"] = plot_df["Dataset"].replace(dataset_names)

inference_plot_df = inference_df.copy()
if not inference_plot_df.empty:
    inference_plot_df["Model"] = inference_plot_df["Model"].replace(model_names)
    inference_plot_df["Mode"] = inference_plot_df["Mode"].replace(mode_names)
    inference_plot_df["Dataset"] = inference_plot_df["Dataset"].replace(dataset_names)
    inference_plot_df["Milliseconds"] = inference_plot_df["Seconds"] * 1000

mean_metrics = (
    plot_df.groupby(["Model", "Dataset", "Division type", "Metric", "Mode"], as_index=False)
    .agg(mean_value=("Value", "mean"), std_value=("Value", "std"))
)
display(mean_metrics)

# %% [markdown]
# ### 3.2.1 Mean metrics by missing pattern

# %%
model_order = ["LOCF", "AE", "SAITS", "BRITS", "RF", "XGBoost", "Transformer", "U-Net"]
model_order = [model for model in model_order if model in mean_metrics["Model"].unique()]
mode_order = ["Single", "Block 20", "Block 100", "Profile"]
palette = sns.color_palette(
    ["darkgray", "blueviolet", "dodgerblue", "lightskyblue",
     "forestgreen", "palegreen", "darkorange", "gold"],
    n_colors=max(len(model_order), 1),
)

fig_dir = Path(OUTPUT_DIR) / "figs"
fig_dir.mkdir(parents=True, exist_ok=True)
sns.set_theme(style="whitegrid", context="talk")

for metric in mean_metrics["Metric"].unique():
    metric_data = mean_metrics[mean_metrics["Metric"] == metric]
    grid = sns.catplot(
        data=metric_data, x="Mode", y="mean_value", hue="Model", col="Dataset",
        kind="bar", order=mode_order, hue_order=model_order,
        height=5, aspect=1.45, sharey=True, palette=palette, errorbar=None,
    )
    grid.set_axis_labels("Missing pattern", f"Mean {metric.upper()}")
    grid.set_titles("")
    sns.move_legend(grid, "upper center", bbox_to_anchor=(0.5, 1.08), ncol=max(len(model_order), 1))
    grid.savefig(fig_dir / f"{metric}.png", dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 3.3 Visualize uncertainty results (QRF and BayesNN)

# %%
uncertainty_pattern = re.compile(
    r"^validation-(picp|mpiw)-([^:]+):\s*(.+)$"
)
uncertainty_records = []

for log_path in sorted(Path(OUTPUT_DIR).rglob("*_*.log")):
    model, dataset = log_path.stem.split("_", 1)
    latest = {}
    for line in log_path.read_text(errors="replace").splitlines():
        match = uncertainty_pattern.match(line.strip())
        if match:
            latest[(match.group(1), match.group(2))] = [
                float(value) for value in match.group(3).split()
            ]
    for (metric, mode), values in latest.items():
        for fold, value in enumerate(values):
            uncertainty_records.append([model, dataset, metric, mode, fold, value])

uncertainty_df = pd.DataFrame(
    uncertainty_records,
    columns=["Model", "Dataset", "Metric", "Mode", "Fold", "Value"],
)
if uncertainty_df.empty:
    print("Run the QRF or BayesNN cells to generate uncertainty results.")
else:
    uncertainty_df["Model"] = uncertainty_df["Model"].replace({"qrf": "QRF", "bayesnn": "BayesNN"})
    uncertainty_df["Mode"] = uncertainty_df["Mode"].replace(mode_names)
    display(
        uncertainty_df.groupby(["Model", "Dataset", "Metric", "Mode"], as_index=False)
        .agg(mean_value=("Value", "mean"), std_value=("Value", "std"))
    )
    print("Raw lower/median/upper predictions are in each model's uncertainty/*.npz folder.")

# %% [markdown]
# ### 3.3.1 Coverage and interval width

# %%
uncertainty_fig_dir = Path(OUTPUT_DIR) / "figs"
uncertainty_fig_dir.mkdir(parents=True, exist_ok=True)

if uncertainty_df.empty:
    print("No uncertainty metrics to plot. Run QRF or BayesNN first.")
else:
    metric_settings = {
        "picp": ("Prediction interval coverage (PICP)", (0, 1)),
        "mpiw": ("Mean prediction interval width (MPIW)", None),
    }
    for metric, (y_label, y_limits) in metric_settings.items():
        metric_data = uncertainty_df[uncertainty_df["Metric"] == metric]
        if metric_data.empty:
            continue
        grid = sns.catplot(
            data=metric_data, x="Mode", y="Value", hue="Model", col="Dataset",
            kind="bar", order=["Single", "Block 20", "Block 100", "Profile"],
            errorbar="sd", capsize=0.08, height=5, aspect=1.35, palette="Set2",
        )
        grid.set_axis_labels("Missing pattern", y_label)
        grid.set_titles("")
        for axis in grid.axes.flat:
            if metric == "picp":
                axis.axhline(0.90, color="crimson", linestyle="--", linewidth=1.5, label="Nominal 90%")
                axis.legend()
            if y_limits is not None:
                axis.set_ylim(*y_limits)
        grid.fig.subplots_adjust(top=0.82)
        grid.fig.suptitle(y_label)
        grid.savefig(uncertainty_fig_dir / f"uncertainty_{metric}.png", dpi=150, bbox_inches="tight")
        plt.show()

# %% [markdown]
# ### 3.3.2 Predictive interval along a log sequence

# %%
import numpy as np

# Set this to a specific .npz path to inspect another fold or missing pattern.
UNCERTAINTY_FILE = None
available_files = sorted(Path(OUTPUT_DIR).rglob("uncertainty/*.npz"))
profile_files = [path for path in available_files if "profile" in path.stem]

if UNCERTAINTY_FILE is not None:
    selected_file = Path(UNCERTAINTY_FILE)
elif profile_files:
    selected_file = profile_files[0]
elif available_files:
    selected_file = available_files[0]
else:
    selected_file = None

if selected_file is None:
    print("No uncertainty .npz artifacts found. Run QRF or BayesNN first.")
else:
    with np.load(selected_file) as artifact:
        indices = artifact["indices"]
        target = artifact["target"]
        prediction = artifact["prediction"]
        lower = artifact["lower"]
        upper = artifact["upper"]

    # Select the sequence/feature pair with the most masked depth samples.
    sequence_feature = indices[:, [0, 2]]
    unique_pairs, inverse, counts = np.unique(
        sequence_feature, axis=0, return_inverse=True, return_counts=True
    )
    pair_id = int(np.argmax(counts))
    selected = inverse == pair_id
    depth_order = np.argsort(indices[selected, 1])
    depth = indices[selected, 1][depth_order]
    truth = target[selected][depth_order]
    median = prediction[selected][depth_order]
    q_low = lower[selected][depth_order]
    q_high = upper[selected][depth_order]
    covered = (truth >= q_low) & (truth <= q_high)
    sequence_id, feature_id = unique_pairs[pair_id]

    fig, axis = plt.subplots(figsize=(14, 6))
    axis.fill_between(depth, q_low, q_high, color="cornflowerblue", alpha=0.28, label="90% predictive interval")
    axis.plot(depth, median, color="navy", linewidth=1.8, label="Median prediction")
    axis.scatter(depth[covered], truth[covered], color="forestgreen", s=20, label="Ground truth inside interval", zorder=3)
    axis.scatter(depth[~covered], truth[~covered], color="crimson", marker="x", s=35, label="Ground truth outside interval", zorder=3)
    axis.set(
        title=f"{selected_file.parents[1].name.upper()} — sequence {sequence_id}, feature {feature_id}",
        xlabel="Depth/sample index within sequence",
        ylabel="Normalized log value",
    )
    axis.legend(ncol=2)
    axis.grid(alpha=0.25)
    fig.tight_layout()
    fig.savefig(uncertainty_fig_dir / f"{selected_file.stem}_interval.png", dpi=150, bbox_inches="tight")
    plt.show()
    print(f"Displayed: {selected_file}")
